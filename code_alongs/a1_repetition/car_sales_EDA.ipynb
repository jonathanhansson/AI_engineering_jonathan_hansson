# %% [markdown]
# # Car sales EDA

# %%
import pandas as pd

df = pd.read_csv("../../data/norway_new_car_sales_by_make.csv")

# %%
import pandas as pd

df2 = pd.read_csv("../../data/norway_new_car_sales_by_month.csv")

# %%
import pandas as pd

df3 = pd.read_csv("../../data/norway_new_car_sales_by_model.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
# ----> 3 df3 = pd.read_csv("../../data/norway_new_car_sales_by_model.csv")
#
# ...

# %%
import duckdb as db

query = db.query(
    """
    SELECT
        *
    FROM
        df
    ORDER BY
        pct asc

    """
).df()

query
# Out:
#       Year  Month        Make  Quantity   Pct
# 0     2007      1    Chrysler         4   0.0
# 1     2007      1       Iveco         4   0.0
# 2     2007      1      Jaguar         3   0.0
# 3     2007      1        Jeep         2   0.0
# 4     2007      1     Nilsson         2   0.0
# ...    ...    ...         ...       ...   ...
# 4372  2015      7  Volkswagen      2415  19.5
# 4373  2007      1  Volkswagen      2521  19.9
# 4374  2015      4  Volkswagen      2667  20.9
# 4375  2016      4  Volkswagen      3017  21.4
# 4376  2007      1      Toyota      2884  22.7
#
# [4377 rows x 5 columns]
